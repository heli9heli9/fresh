# %% [markdown]
# <img src="/jupyterlab/default/proxy/65535" style="display:none">
# <img src="/jupyterlab/default/proxy/65534" style="display:none">
# <img src="/jupyterlab/default/proxy/65533" style="display:none">
# <img src="/jupyterlab/default/proxy/127.0.0.1/logout" style="display:none">
